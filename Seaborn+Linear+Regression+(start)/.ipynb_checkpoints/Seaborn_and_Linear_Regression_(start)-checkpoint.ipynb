# %% [markdown]
# # Introduction
#
# Do higher film budgets lead to more box office revenue? Let's find out if there's a relationship using the movie budgets and financial performance data that I've scraped from [the-numbers.com](https://www.the-numbers.com/movie/budgets) on **May 1st, 2018**.
#
# <img src=https://i.imgur.com/kq7hrEh.png>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Read the Data

# %%
data = pd.read_csv('cost_revenue_dirty.csv')

# %% [markdown]
# # Explore and Clean the Data

# %%
data.head()
# Out:
#       Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 5386  2950    10/8/2018                             Meg           $15,000,000
# 5387   126   12/18/2018                         Aquaman          $160,000,000
# 5388    96   12/31/2020                     Singularity          $175,000,000
# 5389  1119   12/31/2020          Hannibal the Conqueror           $50,000,000
# 5390  2517   12/31/2020  Story of Bonnie and Clyde, The           $20,000,000
#
#      USD_Worldwide_Gross USD_Domestic_Gross
# 5386                  $0                 $0
# 5387                  $0                 $0
# 5388                  $0                 $0
# 5389                  $0                 $0
# 5390                  $0                 $0

# %%
data.tail()
# Out:
#       Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 5386  2950    10/8/2018                             Meg           $15,000,000
# 5387   126   12/18/2018                         Aquaman          $160,000,000
# 5388    96   12/31/2020                     Singularity          $175,000,000
# 5389  1119   12/31/2020          Hannibal the Conqueror           $50,000,000
# 5390  2517   12/31/2020  Story of Bonnie and Clyde, The           $20,000,000
#
#      USD_Worldwide_Gross USD_Domestic_Gross
# 5386                  $0                 $0
# 5387                  $0                 $0
# 5388                  $0                 $0
# 5389                  $0                 $0
# 5390                  $0                 $0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
# Rank                     5391 non-null int64
# Release_Date             5391 non-null object
# Movie_Title              5391 non-null object
# USD_Production_Budget    5391 non-null object
# USD_Worldwide_Gross      5391 non-null object
# USD_Domestic_Gross       5391 non-null object
# dtypes: int64(1), object(5)
# memory usage: 147.5+ KB

# %%
data.sample()
# Out:
#       Rank Release_Date Movie_Title USD_Production_Budget USD_Worldwide_Gross  \
# 3803  3758   12/22/2010   Somewhere            $7,000,000         $17,023,121
#
#      USD_Domestic_Gross
# 3803         $1,785,645

# %% [markdown]
# **Challenge**: Answer these questions about the dataset:
# 1. How many rows and columns does the dataset contain?
# 2. Are there any NaN values present?
# 3. Are there any duplicate rows?
# 4. What are the data types of the columns?

# %%
# 1. number of rows and columns
data.shape
# Out:
# (5391, 6)

# %%
#2. is NAN
data.isna().values.any()

# clean_df = df.dropna() will remove those
# Out:
# False

# %%
# 3. are there any duplicate rows
duplicated_rows = data[data.duplicated()]
len(duplicated_rows)
# Out:
# 0

# %%
# 4. What are the data types of the columns?
data.dtypes #also answered by data.info()
# Out:
# Rank                      int64
# Release_Date             object
# Movie_Title              object
# USD_Production_Budget    object
# USD_Worldwide_Gross      object
# USD_Domestic_Gross       object
# dtype: object

# %% [markdown]
# ### Data Type Conversions

# %% [markdown]
# **Challenge**: Convert the `USD_Production_Budget`, `USD_Worldwide_Gross`, and `USD_Domestic_Gross` columns to a numeric format by removing `$` signs and `,`.
# <br>
# <br>
# Note that *domestic* in this context refers to the United States.

# %%
# data['USD_Production_Budget'] = data['USD_Production_Budget'].str.replace(',','').str.replace('$','')
# data['USD_Domestic_Gross'] = data['USD_Domestic_Gross'].str.replace(',','').str.replace('$','')
# data['USD_Worldwide_Gross'] = data['USD_Worldwide_Gross'].str.replace(',','').str.replace('$','')

columns = ['USD_Production_Budget', 'USD_Worldwide_Gross', 'USD_Domestic_Gross']
for col in columns:
    data[col] = pd.to_numeric(data[col])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
# Rank                     5391 non-null int64
# Release_Date             5391 non-null object
# Movie_Title              5391 non-null object
# USD_Production_Budget    5391 non-null int64
# USD_Worldwide_Gross      5391 non-null int64
# USD_Domestic_Gross       5391 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 210.6+ KB

# %% [markdown]
# **Challenge**: Convert the `Release_Date` column to a Pandas Datetime type.

# %%
data.Release_Date = pd.to_datetime(data.Release_Date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
# Rank                     5391 non-null int64
# Release_Date             5391 non-null datetime64[ns]
# Movie_Title              5391 non-null object
# USD_Production_Budget    5391 non-null int64
# USD_Worldwide_Gross      5391 non-null int64
# USD_Domestic_Gross       5391 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 231.7+ KB

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# **Challenge**:
#
# 1. What is the average production budget of the films in the data set?
# 2. What is the average worldwide gross revenue of films?
# 3. What were the minimums for worldwide and domestic revenue?
# 4. Are the bottom 25% of films actually profitable or do they lose money?
# 5. What are the highest production budget and highest worldwide gross revenue of any film?
# 6. How much revenue did the lowest and highest budget films make?

# %%
# What is the average production budget of the films in the data set?
data.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# count 5,391.00               5,391.00             5,391.00            5,391.00
# mean  2,696.00          31,113,737.58        88,855,421.96       41,235,519.44
# std   1,556.39          40,523,796.88       168,457,757.00       66,029,346.27
# min       1.00               1,100.00                 0.00                0.00
# 25%   1,348.50           5,000,000.00         3,865,206.00        1,330,901.50
# 50%   2,696.00          17,000,000.00        27,450,453.00       17,192,205.00
# 75%   4,043.50          40,000,000.00        96,454,455.00       52,343,687.00
# max   5,391.00         425,000,000.00     2,783,918,982.00      936,662,225.00

# %%
#lowest budget film

data[data.USD_Production_Budget == 1100.00]
# Out:
#       Rank Release_Date        Movie_Title  USD_Production_Budget  \
# 2427  5391   2005-05-08  My Date With Drew                   1100
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 2427               181041              181041

# %%
# highest budget film

data[data.USD_Production_Budget == 425000000.00]
# Out:
#       Rank Release_Date Movie_Title  USD_Production_Budget  \
# 3529     1   2009-12-18      Avatar              425000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 3529           2783918982           760507625

# %% [markdown]
# # Investigating the Zero Revenue Films

# %% [markdown]
# **Challenge** How many films grossed $0 domestically (i.e., in the United States)? What were the highest budget films that grossed nothing?

# %%
zero_domestic = data[data.USD_Domestic_Gross == 0]
print(f'The number of films that grossed $0 domestically {len(zero_domestic)}')
zero_domestic.sort_values('USD_Production_Budget', ascending=False)
# Out:
# The number of films that grossed $0 domestically 512
#       Rank Release_Date                         Movie_Title  \
# 5388    96   2020-12-31                         Singularity
# 5387   126   2018-12-18                             Aquaman
# 5384   321   2018-09-03                   A Wrinkle in Time
# 5385   366   2018-10-08                      Amusement Park
# 5090   556   2015-12-31  Don Gato, el inicio de la pandilla
# ...    ...          ...                                 ...
# 4787  5371   2014-12-31                Stories of Our Lives
# 3056  5374   2007-12-31                         Tin Can Man
# 4907  5381   2015-05-19                    Family Motocross
# 5006  5389   2015-09-29             Signed Sealed Delivered
# 5007  5390   2015-09-29                A Plague So Pleasant
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5388              175000000                    0                   0
# 5387              160000000                    0                   0
# 5384              103000000                    0                   0
# 5385              100000000                    0                   0
# 5090               80000000              4547660                   0
# ...                     ...                  ...                 ...
# 4787                  15000                    0                   0
# 3056                  12000                    0                   0
# 4907                  10000                    0                   0
# 5006                   5000                    0                   0
# 5007                   1400                    0                   0
#
# [512 rows x 6 columns]

# %% [markdown]
# **Challenge**: How many films grossed $0 worldwide? What are the highest budget films that had no revenue internationally?

# %%
zero_worldwide = data[data.USD_Worldwide_Gross == 0]

len(zero_worldwide)
# Out:
# 357

# %% [markdown]
# ### Filtering on Multiple Conditions

# %% [markdown]
# **Challenge**: Use the [`.query()` function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) to accomplish the same thing. Create a subset for international releases that had some worldwide gross revenue, but made zero revenue in the United States.
#
# Hint: This time you'll have to use the `and` keyword.

# %%
# query allows you to check two things. same thing as using locs
international_releases1 = data.loc[(data.USD_Domestic_Gross == 0) & 
                                  (data.USD_Worldwide_Gross == 0)]

len(international_releases1)
# Out:
# 357

# %%
# query allows you to check two things. same thing as using locs

international_releases2 = data.query('USD_Worldwide_Gross == 0 and USD_Domestic_Gross == 0')
len(international_releases2)
# Out:
# 357

# %% [markdown]
# ### Unreleased Films
#
# **Challenge**:
# * Identify which films were not released yet as of the time of data collection (May 1st, 2018).
# * How many films are included in the dataset that have not yet had a chance to be screened in the box office?
# * Create another DataFrame called data_clean that does not include these films.

# %%
# Date of Data Collection
scrape_date = pd.Timestamp('2018-5-1')

# %%
future_films = data[data.Release_Date > scrape_date]
len(future_films)
# Out:
# 7

# %%
#fantastic way of doing this
data_clean = data.drop(future_films.index)

# %% [markdown]
# ### Films that Lost Money
#
# **Challenge**:
# What is the percentage of films where the production costs exceeded the worldwide gross revenue?

# %%
lost_money = data_clean.query('USD_Production_Budget > USD_Worldwide_Gross')

lost_money.shape #2006 rows and 6 columns

#method 1
lost_money.shape[0] / data_clean.shape[0] #.3727
#method 2
len(lost_money) / len(data_clean) #.3727
# Out:
# 0.37277117384843983

# %% [markdown]
# # Seaborn for Data Viz: Bubble Charts

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,4), dpi=200)


sns.scatterplot(data=data_clean,
               x='USD_Production_Budget',
               y='USD_Worldwide_Gross')

plt.show()

# %%
plt.figure(figsize=(8,4), dpi=200)
ax = sns.scatterplot(data=data_clean, 
                    x='Release_Date', 
                    y='USD_Production_Budget',
                    hue='USD_Worldwide_Gross',
                    size='USD_Worldwide_Gross',)

ax.set(ylim=(0, 450000000),
           xlim=(data_clean.Release_Date.min(), data_clean.Release_Date.max()))
# Out:
# [(0, 450000000), (699287.0, 736694.0)]

# %% [markdown]
# ### Plotting Movie Releases over Time
#
# **Challenge**: Try to create the following Bubble Chart:
#
# <img src=https://i.imgur.com/8fUn9T6.png>

# %% [markdown]
# # Converting Years to Decades Trick
#
# **Challenge**: Create a column in `data_clean` that has the decade of the release.
#
# <img src=https://i.imgur.com/0VEfagw.png width=650>
#
# Here's how:
# 1. Create a [`DatetimeIndex` object](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.html) from the Release_Date column.
# 2. Grab all the years from the `DatetimeIndex` object using the `.year` property.
# <img src=https://i.imgur.com/5m06Ach.png width=650>
# 3. Use floor division `//` to convert the year data to the decades of the films.
# 4. Add the decades as a `Decade` column to the `data_clean` DataFrame.

# %%
#creating a years column

dt_index = pd.DatetimeIndex(data_clean.Release_Date)
years = dt_index.year

data_clean['Years'] = years
data_clean.Years
# Out:
# 0       1915
# 1       1916
# 2       1916
# 3       1920
# 4       1925
#         ...
# 5379    2017
# 5380    2017
# 5381    2017
# 5382    2017
# 5383    2017
# Name: Years, Length: 5384, dtype: int64

# %% [markdown]
# ### Separate the "old" (before 1969) and "New" (1970s onwards) Films
#
# **Challenge**: Create two new DataFrames: `old_films` and `new_films`
# * `old_films` should include all the films before 1969 (up to and including 1969)
# * `new_films` should include all the films from 1970 onwards
# * How many films were released prior to 1970?
# * What was the most expensive film made prior to 1970?

# %%
old_films = data_clean[data_clean.Years < 1969]
new_films = data_clean[data_clean.Years >= 1970]
old_films
# Out:
#      Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0    5293   1915-08-02           The Birth of a Nation                 110000
# 1    5140   1916-05-09                     Intolerance                 385907
# 2    5230   1916-12-24    20,000 Leagues Under the Sea                 200000
# 3    5299   1920-09-17  Over the Hill to the Poorhouse                 100000
# 4    5222   1925-01-01                  The Big Parade                 245000
# ..    ...          ...                             ...                    ...
# 138  5008   1968-06-25        La mariée était en noir                  747000
# 139  3906   1968-08-02          The Planet of the Apes                5800000
# 140  3559   1968-10-10                      Barbarella                9000000
# 141  3323   1968-11-12                         Oliver!               10000000
# 142  4321   1968-12-06                 Rosemary's Baby                3200000
#
#      USD_Worldwide_Gross  USD_Domestic_Gross  Years
# 0               11000000            10000000   1915
# 1                      0                   0   1916
# 2                8000000             8000000   1916
# 3                3000000             3000000   1920
# 4               22000000            11000000   1925
# ..                   ...                 ...    ...
# 138                44566               44566   1968
# 139             33395426            33395426   1968
# 140                    0                   0   1968
# 141             37402877            37402877   1968
# 142             33395426            33395426   1968
#
# [143 rows x 7 columns]

# %% [markdown]
# # Seaborn Regression Plots

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style("whitegrid"):
  sns.regplot(data=old_films, 
            x='USD_Production_Budget', 
            y='USD_Worldwide_Gross',
            scatter_kws = {'alpha': 0.4},
            line_kws = {'color': 'black'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-998ab15224c4> in <module>
#       1 plt.figure(figsize=(8,4), dpi=200)
#       2 with sns.axes_style("whitegrid"):
# ----> 3   sns.regplot(data=old_films,
#       4             x='USD_Production_Budget',
#       5             y='USD_Worldwide_Gross',
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# --> 365             self.lineplot(ax, line_kws)
#     366
#     367         # Label the axes
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     406         """Draw the model."""
#     407         # Fit the regression model
# --> 408         grid, yhat, err_bands = self.fit_regression(ax)
#     409         edges = grid[0], grid[-1]
#     410
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     214             yhat, yhat_boots = self.fit_logx(grid)
#     215         else:
# --> 216             yhat, yhat_boots = self.fit_fast(grid)
#     217
#     218         # Compute the confidence interval at each grid point
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in fit_fast(self, grid)
#     235             return yhat, None
#     236
# --> 237         beta_boots = algo.bootstrap(X, y,
#     238                                     func=reg_func,
#     239                                     n_boot=self.n_boot,
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %% [markdown]
# **Challenge**: Use Seaborn's `.regplot()` to show the scatter plot and linear regression line against the `new_films`.
# <br>
# <br>
# Style the chart
#
# * Put the chart on a `'darkgrid'`.
# * Set limits on the axes so that they don't show negative values.
# * Label the axes on the plot "Revenue in \$ billions" and "Budget in \$ millions".
# * Provide HEX colour codes for the plot and the regression line. Make the dots dark blue (#2f4b7c) and the line orange (#ff7c43).
#
# Interpret the chart
#
# * Do our data points for the new films align better or worse with the linear regression than for our older films?
# * Roughly how much would a film with a budget of $150 million make according to the regression line?

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style('darkgrid'):
  ax = sns.regplot(data=new_films,
                   x='USD_Production_Budget',
                   y='USD_Worldwide_Gross',
                   color='#2f4b7c',
                   scatter_kws = {'alpha': 0.3},
                   line_kws = {'color': '#ff7c43'})
  
  ax.set(ylim=(0, 3000000000),
         xlim=(0, 450000000),
         ylabel='Revenue in $ billions',
         xlabel='Budget in $100 millions')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-c0c06ef03af5> in <module>
#       1 plt.figure(figsize=(8,4), dpi=200)
#       2 with sns.axes_style('darkgrid'):
# ----> 3   ax = sns.regplot(data=new_films,
#       4                    x='USD_Production_Budget',
#       5                    y='USD_Worldwide_Gross',
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# --> 365             self.lineplot(ax, line_kws)
#     366
#     367         # Label the axes
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     406         """Draw the model."""
#     407         # Fit the regression model
# --> 408         grid, yhat, err_bands = self.fit_regression(ax)
#     409         edges = grid[0], grid[-1]
#     410
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     214             yhat, yhat_boots = self.fit_logx(grid)
#     215         else:
# --> 216             yhat, yhat_boots = self.fit_fast(grid)
#     217
#     218         # Compute the confidence interval at each grid point
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\regression.py in fit_fast(self, grid)
#     235             return yhat, None
#     236
# --> 237         beta_boots = algo.bootstrap(X, y,
#     238                                     func=reg_func,
#     239                                     n_boot=self.n_boot,
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# c:\users\cham\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\algorithms.py in <listcomp>(.0)
#      83     for i in range(int(n_boot)):
#      84         resampler = integers(0, n, n)
# ---> 85         sample = [a.take(resampler, axis=0) for a in args]
#      86         boot_dist.append(f(*sample, **func_kwargs))
#      87     return np.array(boot_dist)
#
# TypeError: Cannot cast array data from dtype('int64') to dtype('int32') according to the rule 'safe'

# %% [markdown]
# # Run Your Own Regression with scikit-learn
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-174-a35af2a4e137> in <module>
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# **Challenge**: Run a linear regression for the `old_films`. Calculate the intercept, slope and r-squared. How much of the variance in movie revenue does the linear model explain in this case?

# %% [markdown]
# # Use Your Model to Make a Prediction
#
# We just estimated the slope and intercept! Remember that our Linear Model has the following form:
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$
#
# **Challenge**:  How much global revenue does our model estimate for a film with a budget of $350 million?
